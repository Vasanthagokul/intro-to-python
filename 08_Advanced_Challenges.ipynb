# %% [markdown]
# # 08 - Advanced Challenges
#
# **Estimated Time:** 60-90 minutes
#
# ## 🎯 Learning Objectives
# By the end of this notebook, you will:
# - Solve complex Python problems
# - Apply advanced concepts
# - Build solutions for real-world scenarios
#
# **Think of this as:** A final boss level to test your Python mastery!
#
# ---

# %% [markdown]
# ## 1. Real-World Scenarios 🌍
#
# Let's solve some real-world inspired problems.

# %% [markdown]
# ### Problem 1: Library Management System
# Design a simple library management system with the following features:
# - Add a book
# - Remove a book
# - Search for a book
# - Display all books

# %%
# Your code here
class Library:
    def __init__(self):
        pass  # Replace with your implementation

# Example usage
library = Library()
# Add your test cases here

# %% [markdown]
# ### Problem 2: Data Analysis
# Given a CSV file with sales data, write a program to:
# - Calculate total sales
# - Find the best-selling product
# - Visualize sales trends

# %%
# Your code here
import csv
import matplotlib.pyplot as plt

# Replace with your implementation

# %% [markdown]
# ## 2. Algorithmic Challenges 🧠
#
# Test your algorithmic thinking with these problems.

# %% [markdown]
# ### Problem 3: Sudoku Solver
# Write a program to solve a Sudoku puzzle.

# %%
# Your code here
def solve_sudoku(board):
    pass  # Replace with your implementation

# Test case
board = [
    [5, 3, 0, 0, 7, 0, 0, 0, 0],
    [6, 0, 0, 1, 9, 5, 0, 0, 0],
    [0, 9, 8, 0, 0, 0, 0, 6, 0],
    [8, 0, 0, 0, 6, 0, 0, 0, 3],
    [4, 0, 0, 8, 0, 3, 0, 0, 1],
    [7, 0, 0, 0, 2, 0, 0, 0, 6],
    [0, 6, 0, 0, 0, 0, 2, 8, 0],
    [0, 0, 0, 4, 1, 9, 0, 0, 5],
    [0, 0, 0, 0, 8, 0, 0, 7, 9]
]
solve_sudoku(board)

# %% [markdown]
# ### Problem 4: Pathfinding
# Write a program to find the shortest path in a maze.

# %%
# Your code here
def find_shortest_path(maze):
    pass  # Replace with your implementation

# Test case
maze = [
    [1, 0, 0, 0],
    [1, 1, 0, 1],
    [0, 1, 0, 0],
    [1, 1, 1, 1]
]
find_shortest_path(maze)

# %% [markdown]
# ---
#
# ## 🎉 Congratulations!
#
# You've completed the advanced challenges! You now have:
# - ✅ Mastery of Python concepts
# - ✅ Confidence in solving real-world problems
# - ✅ A strong foundation for advanced programming
#
# **Next Steps:** Keep practicing and exploring new challenges!
