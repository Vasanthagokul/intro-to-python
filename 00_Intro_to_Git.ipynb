# %% [markdown]
# # 00 - Introduction to Git
#
# **Estimated Time:** 20-25 minutes
#
# ## 🎯 Learning Objectives
# By the end of this notebook, you will:
# - Understand what Git is and why it is used
# - Learn basic Git commands for version control
# - Create and manage repositories
# - Track changes and collaborate using Git
# - Use GitHub to host and share your code
#
# **Think of this as:** Learning how to save and manage your code like a pro!
#
# ---

# %% [markdown]
# ## 1. What is Git?
#
# Git is a **version control system** that helps you:
# - Track changes in your code
# - Collaborate with others
# - Revert to previous versions if needed
#
# Think of Git as a time machine for your code!
#
# ---

# %% [markdown]
# ## 2. Setting Up Git
#
# Before using Git, you need to configure it. Run the following commands in your terminal:
#
# ```bash
# # Set your name
# git config --global user.name "Your Name"
#
# # Set your email
# git config --global user.email "your.email@example.com"
#
# # Check your configuration
# git config --list
# ```
#
# ---

# %% [markdown]
# ## 3. Creating a Repository
#
# A repository (or repo) is where your project lives.
#
# ### Steps:
# 1. Navigate to your project folder
# 2. Initialize a Git repository
#
# ```bash
# # Navigate to your project folder
# cd path/to/your/project
#
# # Initialize Git
# git init
# ```
#
# This creates a `.git` folder to track your changes.
#
# ---

# %% [markdown]
# ## 4. Tracking Changes
#
# Git tracks changes in your files.
#
# ### Steps:
# 1. Add files to the staging area
# 2. Commit changes
#
# ```bash
# # Add files
# git add filename
#
# # Add all files
# git add .
#
# # Commit changes
# git commit -m "Your commit message"
# ```
#
# ---

# %% [markdown]
# ## 5. Viewing History
#
# You can view the history of your commits.
#
# ```bash
# git log
# ```
#
# Use `q` to exit the log view.
#
# ---

# %% [markdown]
# ## 6. Undoing Changes
#
# Made a mistake? Git can help!
#
# ### Undo staged changes:
# ```bash
# git reset filename
# ```
#
# ### Undo committed changes:
# ```bash
# git revert commit_id
# ```
#
# ---

# %% [markdown]
# ## 7. Collaborating with GitHub
#
# GitHub is a platform to host your repositories online.
#
# ### Steps:
# 1. Create a repository on GitHub
# 2. Link your local repository
#
# ```bash
# # Add remote repository
# git remote add origin https://github.com/username/repo-name.git
#
# # Push changes
# git push -u origin main
# ```
#
# ---

# %% [markdown]
# ## 8. Practice Exercises
#
# Time to practice your Git skills!
#
# ### Exercise 1: Initialize a Repository
# 1. Create a new folder
# 2. Initialize a Git repository
# 3. Add a file and commit it
#
# ### Exercise 2: Push to GitHub
# 1. Create a repository on GitHub
# 2. Push your local repository
#
# ### Exercise 3: Collaborate
# 1. Clone a repository
# 2. Make changes and push them
#
# ---

# %% [markdown]
# ## 🎉 Congratulations!
#
# You've learned the basics of Git and GitHub! You now know:
# - ✅ What Git is and why it's useful
# - ✅ How to create and manage repositories
# - ✅ How to track changes and view history
# - ✅ How to collaborate using GitHub
#
# **Next:** Move on to `01_Python_Basics.ipynb` to start your Python journey!
